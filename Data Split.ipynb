# %%
import numpy as np
import json
import pandas as pd

# %%
df=pd.read_csv('Lv3_UMDOTS_Escooters/Data_Lv3_UMDOTS_Escooters.csv',converters={'PATH':json.loads}, header=0)

# %%
df.head()
# Out:
#                      CREATED                      START  \
# 0  2020-10-03 03:32:15+00:00  2020-10-03 03:32:15+00:00
# 1  2020-10-03 03:07:39+00:00  2020-10-03 03:07:39+00:00
# 2  2020-10-03 03:17:05+00:00  2020-10-03 03:17:05+00:00
# 3  2020-10-03 02:24:58+00:00  2020-10-03 02:24:58+00:00
# 4  2020-10-03 03:19:34+00:00  2020-10-03 03:19:34+00:00
#
#                          END  DISTANCE  RIDE_ID  CUSTOMER_ID  MINUTES  \
# 0  2020-10-03 03:32:46+00:00     0.008  3135665       193964        1
# 1  2020-10-03 03:37:06+00:00     1.062  3135395       542947       30
# 2  2020-10-03 03:24:24+00:00     0.847  3135503       517321        8
# 3  2020-10-03 03:11:56+00:00     3.447  3134955       578051       47
# 4  2020-10-03 03:22:45+00:00     0.386  3135529       552305        4
#
#   VEHICLE_TYPE                                               PATH  \
# 0      Scooter  {'coordinates': [[-76.934163, 38.9906555], [-7...
# 1      Scooter  {'coordinates': [[-76.93818083333333, 38.98208...
# ...

# %%
df1 = pd.concat([df.drop(['PATH'], axis=1), df['PATH'].apply(pd.Series)], axis=1)

# %%
df1.head()
# Out:
#                      CREATED                      START  \
# 0  2020-10-03 03:32:15+00:00  2020-10-03 03:32:15+00:00
# 1  2020-10-03 03:07:39+00:00  2020-10-03 03:07:39+00:00
# 2  2020-10-03 03:17:05+00:00  2020-10-03 03:17:05+00:00
# 3  2020-10-03 02:24:58+00:00  2020-10-03 02:24:58+00:00
# 4  2020-10-03 03:19:34+00:00  2020-10-03 03:19:34+00:00
#
#                          END  DISTANCE  RIDE_ID  CUSTOMER_ID  MINUTES  \
# 0  2020-10-03 03:32:46+00:00     0.008  3135665       193964        1
# 1  2020-10-03 03:37:06+00:00     1.062  3135395       542947       30
# 2  2020-10-03 03:24:24+00:00     0.847  3135503       517321        8
# 3  2020-10-03 03:11:56+00:00     3.447  3134955       578051       47
# 4  2020-10-03 03:22:45+00:00     0.386  3135529       552305        4
#
#   VEHICLE_TYPE                                         TIMESTAMPS  START LONG  \
# 0      Scooter  [\n  "2020-10-03T03:32:14Z",\n  "2020-10-03T03...  -76.934163
# ...

# %%
df2 = pd.DataFrame(df1.coordinates.tolist(), index= df1.index)

# %%
df3 = pd.concat([df1.drop(['coordinates'], axis=1), df2], axis=1)

# %%
df3.head()
# Out:
#                      CREATED                      START  \
# 0  2020-10-03 03:32:15+00:00  2020-10-03 03:32:15+00:00
# 1  2020-10-03 03:07:39+00:00  2020-10-03 03:07:39+00:00
# 2  2020-10-03 03:17:05+00:00  2020-10-03 03:17:05+00:00
# 3  2020-10-03 02:24:58+00:00  2020-10-03 02:24:58+00:00
# 4  2020-10-03 03:19:34+00:00  2020-10-03 03:19:34+00:00
#
#                          END  DISTANCE  RIDE_ID  CUSTOMER_ID  MINUTES  \
# 0  2020-10-03 03:32:46+00:00     0.008  3135665       193964        1
# 1  2020-10-03 03:37:06+00:00     1.062  3135395       542947       30
# 2  2020-10-03 03:24:24+00:00     0.847  3135503       517321        8
# 3  2020-10-03 03:11:56+00:00     3.447  3134955       578051       47
# 4  2020-10-03 03:22:45+00:00     0.386  3135529       552305        4
#
#   VEHICLE_TYPE                                         TIMESTAMPS  START LONG  \
# 0      Scooter  [\n  "2020-10-03T03:32:14Z",\n  "2020-10-03T03...  -76.934163
# ...

# %%
df3.to_csv('Data_Wide.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40325 entries, 0 to 40324
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CREATED       40325 non-null  object
#  1   START         40325 non-null  object
#  2   END           40325 non-null  object
#  3   DISTANCE      38052 non-null  float64
#  4   RIDE_ID       40325 non-null  int64
#  5   CUSTOMER_ID   40325 non-null  int64
#  6   MINUTES       40325 non-null  int64
#  7   VEHICLE_TYPE  40325 non-null  object
#  8   PATH          40325 non-null  object
#  9   TIMESTAMPS    40325 non-null  object
#  10  START LONG    40325 non-null  float64
#  11  START LAT     40325 non-null  float64
#  12  END LONG      40325 non-null  float64
#  13  END LAT       40325 non-null  float64
# dtypes: float64(5), int64(3), object(6)
# memory usage: 4.3+ MB
